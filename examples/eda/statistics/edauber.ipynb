# %%
import pandas as pd
import scipy.stats as stats

# %% [markdown]
# Download dataset from [https://www.kaggle.com/datasets/deexithreddy/rideshare]

# %%
data = pd.read_csv("rideshare_kaggle.csv")

# %%
data.head()

# %%
data.columns

# %%
len(data)

# %%
data['hour']

# %%
data['mean']

# %%
data['hour'].mean()

# %%
data['hour'].median()

# %%
data['hour'].mode()

# %%
data['price'].mean()

# %%
data['price'].median()

# %%
data['price'].mode()

# %%
data['source'].mode()

# %%
data['destination'].mode()

# %%
stats.trim_mean(data['price'], 0.1)

# %%
data['price'].var()

# %%
data['price'].std()

# %%
data['price'].std() / data['price'].mean()

# %%
data['price'].hist(bins=30)

# %%
data['price'].skew()

# %%
data['price'].kurtosissis()
