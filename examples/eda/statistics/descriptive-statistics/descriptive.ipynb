# %% [markdown]
# # Descriptive

# %%
import pandas as pd
import numpy as np
from scipy import stats

# %%
df = pd.read_csv('../../../../datasets/flights.csv')
df
# Out:
#             id  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 0            0  2013      1    1     517.0             515        2.0
# 1            1  2013      1    1     533.0             529        4.0
# 2            2  2013      1    1     542.0             540        2.0
# 3            3  2013      1    1     544.0             545       -1.0
# 4            4  2013      1    1     554.0             600       -6.0
# ...        ...   ...    ...  ...       ...             ...        ...
# 336771  336771  2013      9   30       NaN            1455        NaN
# 336772  336772  2013      9   30       NaN            2200        NaN
# 336773  336773  2013      9   30       NaN            1210        NaN
# 336774  336774  2013      9   30       NaN            1159        NaN
# 336775  336775  2013      9   30       NaN             840        NaN
#
#         arr_time  sched_arr_time  arr_delay  ... flight  tailnum origin dest  \
# ...

# %% [markdown]
# 1. Mean

# %%
df["arr_delay"].mean()
# Out:
# np.float64(6.89537675731489)

# %%
stats.trim_mean(df["arr_delay"],0.1)
# Out:
# np.float64(0.9612355338465307)

# %%
df["arr_delay"].median()
# Out:
# np.float64(-5.0)

# %%
df["arr_delay"].mode()
# Out:
# 0   -13.0
# Name: arr_delay, dtype: float64

# %% [markdown]
# 2. Variance

# %%
df["arr_delay"].var()
# Out:
# np.float64(1992.13072710194)

# %%
df["arr_delay"].hist(bins=200)
# Out:
# <Axes: >

# %%
df["arr_delay"][df["arr_delay"] < 100].hist(bins=80)
# Out:
# <Axes: >

# %% [markdown]
# 3. Skewness

# %%
df["arr_delay"].skew()
# Out:
# np.float64(3.7168174804571863)

# %% [markdown]
# 4. Kurtosis

# %%
df["arr_delay"].kurtosis()
# Out:
# np.float64(29.233043998766775)

# %%
df['distance_time'] = df['arr_time'] - df['dep_time']

# %%
df
# Out:
#             id  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 0            0  2013      1    1     517.0             515        2.0
# 1            1  2013      1    1     533.0             529        4.0
# 2            2  2013      1    1     542.0             540        2.0
# 3            3  2013      1    1     544.0             545       -1.0
# 4            4  2013      1    1     554.0             600       -6.0
# ...        ...   ...    ...  ...       ...             ...        ...
# 336771  336771  2013      9   30       NaN            1455        NaN
# 336772  336772  2013      9   30       NaN            2200        NaN
# 336773  336773  2013      9   30       NaN            1210        NaN
# 336774  336774  2013      9   30       NaN            1159        NaN
# 336775  336775  2013      9   30       NaN             840        NaN
#
#         arr_time  sched_arr_time  arr_delay  ... tailnum  origin dest  \
# ...

# %% [markdown]
# - Corr

# %%
df[["dep_time", 'sched_dep_time', 'dep_delay', 'arr_time', 'sched_arr_time', 'arr_delay', 'distance', 'distance_time']].corr()
# Out:
#                 dep_time  sched_dep_time  dep_delay  arr_time  sched_arr_time  \
# dep_time        1.000000        0.954617   0.260231  0.660779        0.784682
# sched_dep_time  0.954617        1.000000   0.198887  0.642680        0.783342
# dep_delay       0.260231        0.198887   1.000000  0.028729        0.160488
# arr_time        0.660779        0.642680   0.028729  1.000000        0.788997
# sched_arr_time  0.784682        0.783342   0.160488  0.788997        1.000000
# arr_delay       0.232306        0.173896   0.914803  0.024482        0.133261
# distance       -0.013998       -0.017995  -0.021671  0.046991        0.068726
# distance_time  -0.321497       -0.291982  -0.263792  0.498294        0.089099
#
#                 arr_delay  distance  distance_time
# dep_time         0.232306 -0.013998      -0.321497
# sched_dep_time   0.173896 -0.017995      -0.291982
# dep_delay        0.914803 -0.021671      -0.263792
# arr_time         0.024482  0.046991       0.498294
# ...

# %% [markdown]
# - Three Sigma

# %%
a = (df["arr_delay"].mean()) - (2 * df["arr_delay"].std())
a
# Out:
# np.float64(-82.37120662307309)

# %%
b = (df["arr_delay"].mean()) + (2 * df["arr_delay"].std())
b
# Out:
# np.float64(96.16196013770288)

# %%
c = b - a
c
# Out:
# np.float64(178.53316676077597)

# %%
x = (df["arr_delay"].mean()) - (3 * df["arr_delay"].std())
x
# Out:
# np.float64(-127.00449831326708)

# %%
y = (df["arr_delay"].mean()) + (3 * df["arr_delay"].std())
y
# Out:
# np.float64(140.79525182789686)

# %%
z = y - x
z
# Out:
# np.float64(267.79975014116394)
