# %% [markdown]
# # U-Test
# For unnormal data

# %%
from scipy import stats
import numpy as np

# %%
g1 = np.array([20, 23, 21, 25, 18, 17, 18, 24, 20, 24, 23, 19])
g2 = [24, 25, 21, 22, 23, 18, 17, 28, 24, 27, 21, 23]

# %%
np.mean(g1)
# Out:
# np.float64(21.0)

# %%
np.mean(g2)
# Out:
# np.float64(22.75)

# %%
stats.mannwhitneyu(g1, g2, alternative="two-sided")
# Out:
# MannwhitneyuResult(statistic=np.float64(50.0), pvalue=np.float64(0.21138945901258455))

# %%
stats.mannwhitneyu(g1, g2, alternative="greater")
# Out:
# MannwhitneyuResult(statistic=np.float64(50.0), pvalue=np.float64(0.9045433311864579))

# %%
stats.mannwhitneyu(g1, g2, alternative="less")
# Out:
# MannwhitneyuResult(statistic=np.float64(50.0), pvalue=np.float64(0.10569472950629227))
