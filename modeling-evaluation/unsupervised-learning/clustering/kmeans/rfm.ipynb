# %%
import numpy as np
import pandas as pd
import os
from sklearn.cluster import KMeans
import datetime as dt

# %%
dataset = os.path.join('..','..', '..', 'datasets', 'online-retail.csv')
df = pd.read_csv(dataset)
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
df = df[df['CustomerID'].notnull()]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 406829 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    406829 non-null  object
#  1   StockCode    406829 non-null  object
#  2   Description  406829 non-null  object
#  3   Quantity     406829 non-null  int64
#  4   InvoiceDate  406829 non-null  object
#  5   UnitPrice    406829 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      406829 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 27.9+ MB

# %%
df['InvoiceDate'] = df['InvoiceDate'].astype('datetime64[ns]')

# %%
df['InvoiceDay'] = df['InvoiceDate'].apply(lambda x: dt.datetime(x.year, x.month, x.day))

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country InvoiceDay
# ...

# %%
dt.timedelta(1)
# Out:
# datetime.timedelta(days=1)

# %%
pin_date = max(df['InvoiceDay']) + dt.timedelta(1)
pin_date
# Out:
# Timestamp('2011-12-10 00:00:00')

# %%
df['TotalSum'] = df['Quantity'] * df['UnitPrice']
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country InvoiceDay  \
# ...

# %%
rfm = df.groupby(['CustomerID']).agg({
    'InvoiceDay': lambda x: (pin_date - x.max()).days,
    'InvoiceNo': 'count',
    'TotalSum': 'sum'
})
rfm
# Out:
#             InvoiceDay  InvoiceNo  TotalSum
# CustomerID
# 12346.0            326          2      0.00
# 12347.0              3        182   4310.00
# 12348.0             76         31   1797.24
# 12349.0             19         73   1757.55
# 12350.0            311         17    334.40
# ...                ...        ...       ...
# 18280.0            278         10    180.60
# 18281.0            181          7     80.82
# 18282.0              8         13    176.60
# 18283.0              4        756   2094.88
# 18287.0             43         70   1837.28
#
# [4372 rows x 3 columns]

# %%
df[df["CustomerID"] == 12346.0]
# Out:
#       InvoiceNo StockCode                     Description  Quantity  \
# 61619    541431     23166  MEDIUM CERAMIC TOP STORAGE JAR     74215
# 61624   C541433     23166  MEDIUM CERAMIC TOP STORAGE JAR    -74215
#
#               InvoiceDate  UnitPrice  CustomerID         Country InvoiceDay  \
# 61619 2011-01-18 10:01:00       1.04     12346.0  United Kingdom 2011-01-18
# 61624 2011-01-18 10:17:00       1.04     12346.0  United Kingdom 2011-01-18
#
#        TotalSum
# 61619   77183.6
# 61624  -77183.6

# %%
rfm.rename(columns={
    'InvoiceDay': 'Recency',
    'InvoiceNo': 'Frequency',
    'TotalSum': 'Monetary' 
}, inplace=True)
rfm
# Out:
#             Recency  Frequency  Monetary
# CustomerID
# 12346.0         326          2      0.00
# 12347.0           3        182   4310.00
# 12348.0          76         31   1797.24
# 12349.0          19         73   1757.55
# 12350.0         311         17    334.40
# ...             ...        ...       ...
# 18280.0         278         10    180.60
# 18281.0         181          7     80.82
# 18282.0           8         13    176.60
# 18283.0           4        756   2094.88
# 18287.0          43         70   1837.28
#
# [4372 rows x 3 columns]

# %%
r_labels = range(4, 0, -1)
r_groups = pd.qcut(rfm['Recency'], q=4, labels=r_labels)
f_labels = range(1, 5)
f_groups = pd.qcut(rfm['Frequency'], q=4, labels=f_labels)
m_labels = range(1, 5)
m_groups = pd.qcut(rfm['Monetary'], q=4, labels=m_labels)

# %%
rfm['R'] = r_groups.values
rfm['F'] = f_groups.values
rfm['M'] = m_groups.values
rfm
# Out:
#             Recency  Frequency  Monetary  R  F  M
# CustomerID
# 12346.0         326          2      0.00  1  1  1
# 12347.0           3        182   4310.00  4  4  4
# 12348.0          76         31   1797.24  2  2  4
# 12349.0          19         73   1757.55  3  3  4
# 12350.0         311         17    334.40  1  1  2
# ...             ...        ...       ... .. .. ..
# 18280.0         278         10    180.60  1  1  1
# 18281.0         181          7     80.82  1  1  1
# 18282.0           8         13    176.60  4  1  1
# 18283.0           4        756   2094.88  4  4  4
# 18287.0          43         70   1837.28  3  3  4
#
# [4372 rows x 6 columns]

# %%
X = rfm[['R', 'F', 'M']]
kmeans = KMeans(n_clusters=5, init='k-means++', max_iter=300)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=5)

# %%
kmeans.labels_
# Out:
# array([0, 1, 4, ..., 2, 1, 1], shape=(4372,), dtype=int32)

# %%
rfm['kmeans_cluster'] = kmeans.labels_

# %%
rfm
# Out:
#             Recency  Frequency  Monetary  R  F  M  kmeans_cluster
# CustomerID
# 12346.0         326          2      0.00  1  1  1               0
# 12347.0           3        182   4310.00  4  4  4               1
# 12348.0          76         31   1797.24  2  2  4               4
# 12349.0          19         73   1757.55  3  3  4               1
# 12350.0         311         17    334.40  1  1  2               0
# ...             ...        ...       ... .. .. ..             ...
# 18280.0         278         10    180.60  1  1  1               0
# 18281.0         181          7     80.82  1  1  1               0
# 18282.0           8         13    176.60  4  1  1               2
# 18283.0           4        756   2094.88  4  4  4               1
# 18287.0          43         70   1837.28  3  3  4               1
#
# [4372 rows x 7 columns]

# %%
rfm[rfm['kmeans_cluster'] == 4]
# Out:
#             Recency  Frequency  Monetary  R  F  M  kmeans_cluster
# CustomerID
# 12348.0          76         31   1797.24  2  2  4               4
# 12354.0         233         58   1079.40  1  3  3               4
# 12365.0         292         23    320.69  1  2  2               4
# 12372.0          72         52   1298.04  2  3  3               4
# 12377.0         316         77   1628.12  1  3  4               4
# ...             ...        ...       ... .. .. ..             ...
# 18248.0         114         49    783.02  2  3  3               4
# 18250.0         302         22    342.92  1  2  2               4
# 18251.0          88         16   4314.72  2  1  4               4
# 18260.0         173        140   2595.00  1  4  4               4
# 18265.0          73         46    801.51  2  3  3               4
#
# [948 rows x 7 columns]

# %%
customers_g4 = list(rfm[rfm['kmeans_cluster'] == 4].index)
top_products_g4 = df.query('CustomerID == @customers_g4').groupby(['StockCode'])['InvoiceNo'].count().sort_values(ascending=False).head(10)
top_products_g4
# Out:
# StockCode
# 85123A    339
# 22423     304
# 47566     244
# 84879     239
# 22720     206
# 22960     188
# 21212     185
# 85099B    170
# POST      169
# 22457     166
# Name: InvoiceNo, dtype: int64

# %%
rfm[rfm['kmeans_cluster'] == 4][['Recency', 'Frequency', 'Monetary']].mean()
# Out:
# Recency       161.437764
# Frequency      56.681435
# Monetary     1046.675993
# dtype: float64

# %%
rfm[rfm['kmeans_cluster'] == 3][['Recency', 'Frequency', 'Monetary']].mean()
# Out:
# Recency       19.896792
# Frequency     57.719665
# Monetary     998.288718
# dtype: float64

# %%
rfm[rfm['kmeans_cluster'] == 2][['Recency', 'Frequency', 'Monetary']].mean()
# Out:
# Recency       46.018543
# Frequency     23.651656
# Monetary     322.980306
# dtype: float64

# %%
rfm[rfm['kmeans_cluster'] == 1][['Recency', 'Frequency', 'Monetary']].mean()
# Out:
# Recency        21.622486
# Frequency     260.085009
# Monetary     5653.683556
# dtype: float64

# %%
rfm[rfm['kmeans_cluster'] == 0][['Recency', 'Frequency', 'Monetary']].mean()
# Out:
# Recency      208.691142
# Frequency     10.862471
# Monetary     190.051307
# dtype: float64
